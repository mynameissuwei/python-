# %%
import pandas as pd
filename = "tb_bond_jisilu.xlsx"
df = pd.read_excel(filename)
df_copy = df.copy()
# df_copy[df_copy['发出强赎公告'] == 'Y']
# df[df['可转债涨幅']<df['正股涨跌幅']]
# df_copy[df_copy['可转债涨幅'] < 0]
df['涨跌差'] = df['正股涨跌幅'] - df['可转债涨幅']
print(df,'dfff')
# Out:
#       可转债代码 可转债名称   可转债价格  正股名称    正股代码    正股现价  正股涨跌幅  最新转股价     溢价率  可转债涨幅  \
# 0    123042  银河转债  420.33   金银河  300619  104.70   5.76  24.38   -2.12   4.56
# 1    113504  艾华转债  210.09  艾华集团  603989   44.08   2.80  20.81   -0.82   2.07
# 2    123070  鹏辉转债  262.38  鹏辉能源  300438   53.11  -5.16  20.08   -0.80  -3.39
# 3    113603  东缆转债  247.01  东方电缆  603606   58.83  -2.11  23.65   -0.70  -1.50
# 4    123086  海兰转债  266.89   海兰信  300065   19.47  11.96   7.27   -0.34  12.14
# ..      ...   ...     ...   ...     ...     ...    ...    ...     ...    ...
# 365  128041  盛路转债  299.20  盛路通信    2446    6.76   7.64   6.82  201.86   3.92
# 366  113596  城地转债   96.18  城地香江  603887    7.61   2.01  24.26  206.60   1.38
# 367  128062  亚药转债   95.32  亚太药业    2370    4.31  -2.05  16.25  259.43   0.42
# 368  123013  横河转债  319.50  横河精密  300539    7.75   2.51   9.04  272.68  -0.03
# 369  123015  蓝盾转债  235.50  蓝盾股份  300297    3.60  -1.10   5.79  278.74  -0.63
#
# ...
